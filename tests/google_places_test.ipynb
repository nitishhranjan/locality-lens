# %% [markdown]
# # Google Places Data Pull – Quick Assessment
#
# Purpose: pull POIs for a location via Google Places + Geocoding, measure time, and inspect data quality (counts, sample rows, missing fields).
#
# ⚠️ **API key**: set the environment variable `GOOGLE_MAP_API` (or rename to `GOOGLE_MAPS_API_KEY`). **Do not hardcode keys in the notebook.**

# %%
import os, time, requests, math, json
from collections import defaultdict
from typing import List, Dict, Any

API_KEY = os.getenv("GOOGLE_MAP_API") or os.getenv("GOOGLE_MAPS_API_KEY")
if not API_KEY:
    raise ValueError("Set GOOGLE_MAP_API or GOOGLE_MAPS_API_KEY in your environment")

GEOCODE_URL = "https://maps.googleapis.com/maps/api/geocode/json"
PLACES_URL = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
DISTANCE_URL = "https://maps.googleapis.com/maps/api/distancematrix/json"

def geocode_address(address: str):
    params = {"address": address, "key": API_KEY}
    resp = requests.get(GEOCODE_URL, params=params, timeout=20)
    data = resp.json()
    if data.get("status") != "OK":
        raise RuntimeError(f"Geocoding failed: {data.get('status')}")
    loc = data["results"][0]["geometry"]["location"]
    return loc["lat"], loc["lng"], data["results"][0].get("formatted_address")

def fetch_places(location, radius_m: int, place_types: List[str], page_pause: float = 2.0):
    lat, lng = location
    results = []
    next_page_token = None
    while True:
        params = {
            "location": f"{lat},{lng}",
            "radius": radius_m,
            "type": place_types[0],  # one type per query
            "key": API_KEY
        }
        if next_page_token:
            params["pagetoken"] = next_page_token
            time.sleep(page_pause)  # required before using next_page_token

        resp = requests.get(PLACES_URL, params=params, timeout=30)
        data = resp.json()
        status = data.get("status")
        if status not in ("OK", "ZERO_RESULTS"):
            break
        results.extend(data.get("results", []))
        next_page_token = data.get("next_page_token")
        if not next_page_token:
            break
    return results

def summarize_results(raw_results: List[Dict[str, Any]]):
    if not raw_results:
        return {"count": 0, "missing_name": 0, "with_rating": 0, "avg_rating": None}
    missing_name = sum(1 for r in raw_results if not r.get("name"))
    ratings = [r.get("rating") for r in raw_results if r.get("rating") is not None]
    avg_rating = round(sum(ratings)/len(ratings), 2) if ratings else None
    return {
        "count": len(raw_results),
        "missing_name": missing_name,
        "with_rating": len(ratings),
        "avg_rating": avg_rating,
    }

# Category → Google place type mapping (one type per call; adjust as needed)
CATEGORY_TYPES = {
    "schools": ["school"],
    "hospitals": ["hospital"],
    "clinics": ["doctor"],
    "pharmacies": ["pharmacy"],
    "banks": ["bank"],
    "atms": ["atm"],
    "restaurants": ["restaurant"],
    "cafes": ["cafe"],
    "fast_food": ["meal_takeaway"],
    "gyms": ["gym"],
    "libraries": ["library"],
    "worship": ["place_of_worship"],
    "nightlife": ["bar"],
    "cinemas": ["movie_theater"],
    "parks": ["park"],
    "hotels": ["lodging"],
    "shops": ["store"],
    "transit": ["transit_station"],
}

def run_category_pull(location, radius_m=2000):
    summary = {}
    timings = {}
    samples = {}
    for cat, types in CATEGORY_TYPES.items():
        start = time.perf_counter()
        raw = fetch_places(location, radius_m, types)
        elapsed = time.perf_counter() - start
        timings[cat] = elapsed
        summary[cat] = summarize_results(raw)
        samples[cat] = raw[:3]
    return summary, timings, samples

# %%
# Choose a location
address = "Indiranagar, Bangalore"
radius_m = 2000  # 2 km

geo_start = time.perf_counter()
lat, lng, formatted = geocode_address(address)
geo_time = time.perf_counter() - geo_start
print(f"Geocoded '{address}' → {lat:.6f}, {lng:.6f} | {formatted} | {geo_time:.2f}s")

print("\nFetching places per category (Google Places Nearby)...")
summary, timings, samples = run_category_pull((lat, lng), radius_m=radius_m)

print("\n=== Counts & Data Quality ===")
for cat, stats in summary.items():
    print(f"{cat:12s} | count={stats['count']:3d} | missing_name={stats['missing_name']:2d} | with_rating={stats['with_rating']:2d} | avg_rating={stats['avg_rating']}")

print("\n=== Timings (s) ===")
for cat, t in sorted(timings.items(), key=lambda x: x[1], reverse=True):
    print(f"{cat:12s}: {t:.2f}s")

print("\n=== Sample Rows (first 3 per category, if available) ===")
for cat, rows in samples.items():
    if not rows:
        continue
    print(f"\n[{cat}] sample:")
    for r in rows:
        print(json.dumps({
            "name": r.get("name"),
            "types": r.get("types"),
            "rating": r.get("rating"),
            "user_ratings_total": r.get("user_ratings_total"),
            "geometry": r.get("geometry", {}).get("location", {}),
        }, ensure_ascii=False))
# Out:
# Geocoded 'Indiranagar, Bangalore' → 12.978369, 77.640836 | Indiranagar, Bengaluru, Karnataka, India | 0.53s
#
# Fetching places per category (Google Places Nearby)...
#
# === Counts & Data Quality ===
# schools      | count= 60 | missing_name= 0 | with_rating=33 | avg_rating=4.53
# hospitals    | count= 60 | missing_name= 0 | with_rating=41 | avg_rating=4.19
# clinics      | count= 60 | missing_name= 0 | with_rating=57 | avg_rating=4.45
# pharmacies   | count= 60 | missing_name= 0 | with_rating=52 | avg_rating=3.96
# banks        | count= 60 | missing_name= 0 | with_rating=60 | avg_rating=3.25
# atms         | count= 60 | missing_name= 0 | with_rating=58 | avg_rating=2.72
# restaurants  | count= 60 | missing_name= 0 | with_rating=60 | avg_rating=4.03
# cafes        | count= 60 | missing_name= 0 | with_rating=57 | avg_rating=4.28
# fast_food    | count= 60 | missing_name= 0 | with_rating=50 | avg_rating=4.12
# gyms         | count= 60 | missing_name= 0 | with_rating=55 | avg_rating=4.64
# libraries    | count=  8 | missing_name= 0 | with_rating= 8 | avg_rating=4.04
# worship      | count= 60 | missing_name= 0 | with_rating=55 | avg_rating=3.99
# nightlife    | count= 60 | missing_name= 0 | with_rating=55 | avg_rating=4.22
# cinemas      | count=  1 | missing_name= 0 | with_rating= 1 | avg_rating=5.0
# parks        | count= 60 | missing_name= 0 | with_rating=48 | avg_rating=4.16
# hotels       | count= 60 | missing_name= 0 | with_rating=54 | avg_rating=3.95
# shops        | count= 60 | missing_name= 0 | with_rating=58 | avg_rating=4.12
# transit      | count= 60 | missing_name= 0 | with_rating=44 | avg_rating=4.0
#
# === Timings (s) ===
# nightlife   : 7.08s
# hotels      : 7.06s
# fast_food   : 7.00s
# restaurants : 6.95s
# schools     : 6.92s
# hospitals   : 6.88s
# transit     : 6.87s
# worship     : 6.79s
# parks       : 6.68s
# cafes       : 6.65s
# shops       : 6.57s
# pharmacies  : 6.50s
# gyms        : 6.40s
# banks       : 6.33s
# clinics     : 6.28s
# atms        : 6.03s
# cinemas     : 0.83s
# libraries   : 0.67s
#
# === Sample Rows (first 3 per category, if available) ===
#
# [schools] sample:
# {"name": "National Public School", "types": ["school", "point_of_interest", "establishment"], "rating": null, "user_ratings_total": null, "geometry": {"lat": 12.969271, "lng": 77.6468843}}
# {"name": "New Horizon Public School", "types": ["school", "point_of_interest", "establishment"], "rating": null, "user_ratings_total": null, "geometry": {"lat": 12.9675847, "lng": 77.6419487}}
# {"name": "Indiranagar High School , Kerala Samajam IAS Academy", "types": ["secondary_school", "school", "point_of_interest", "establishment"], "rating": null, "user_ratings_total": null, "geometry": {"lat": 12.9798293, "lng": 77.6391163}}
#
# [hospitals] sample:
# {"name": "ESI Hospital Indiranagar", "types": ["hospital", "health", "point_of_interest", "establishment"], "rating": 2.5, "user_ratings_total": 422, "geometry": {"lat": 12.9711854, "lng": 77.63690989999999}}
# {"name": "Heart Lung Clinic", "types": ["hospital", "health", "point_of_interest", "establishment"], "rating": 3.3, "user_ratings_total": 8, "geometry": {"lat": 12.97864, "lng": 77.64442079999999}}
# {"name": "CHCC", "types": ["hospital", "health", "point_of_interest", "establishment"], "rating": 5, "user_ratings_total": 26, "geometry": {"lat": 12.9797577, "lng": 77.6452417}}
#
# [clinics] sample:
# {"name": "Dr Batra’s Homeopathy, Hair & Skin Clinic", "types": ["doctor", "health", "point_of_interest", "establishment"], "rating": 4.5, "user_ratings_total": 1087, "geometry": {"lat": 12.9786706, "lng": 77.6409762}}
# {"name": "JB Homecare - Physiotherapy", "types": ["doctor", "health", "point_of_interest", "store", "establishment"], "rating": 5, "user_ratings_total": 1, "geometry": {"lat": 12.9689281, "lng": 77.6487021}}
# {"name": "Narayana Specialists Dental and Implant Center", "types": ["dentist", "doctor", "health", "point_of_interest", "establishment"], "rating": 4.9, "user_ratings_total": 284, "geometry": {"lat": 12.9718493, "lng": 77.63585929999999}}
#
# [pharmacies] sample:
# {"name": "Apollo Pharmacy Indira Nagar Bangalore", "types": ["pharmacy", "drugstore", "health", "store", "food", "point_of_interest", "establishment"], "rating": 4, "user_ratings_total": 62, "geometry": {"lat": 12.9800108, "lng": 77.6386606}}
# {"name": "The Homeo Center", "types": ["pharmacy", "health", "store", "point_of_interest", "establishment"], "rating": 4.4, "user_ratings_total": 47, "geometry": {"lat": 12.9729883, "lng": 77.6357768}}
# {"name": "Siddhanth Medicals", "types": ["pharmacy", "health", "store", "point_of_interest", "establishment"], "rating": 4.5, "user_ratings_total": 6, "geometry": {"lat": 12.9779652, "lng": 77.63025859999999}}
#
# [banks] sample:
# {"name": "IDBI Bank", "types": ["bank", "atm", "finance", "point_of_interest", "establishment"], "rating": 2.6, "user_ratings_total": 157, "geometry": {"lat": 12.9739087, "lng": 77.6466451}}
# {"name": "Bank of India - Jeevan Bhima Nagar Branch", "types": ["bank", "atm", "finance", "point_of_interest", "establishment"], "rating": 3.4, "user_ratings_total": 66, "geometry": {"lat": 12.9687544, "lng": 77.64945519999999}}
# {"name": "IndusInd Bank", "types": ["bank", "atm", "finance", "point_of_interest", "establishment"], "rating": 2.6, "user_ratings_total": 63, "geometry": {"lat": 12.969979, "lng": 77.647612}}
#
# [atms] sample:
# {"name": "IDBI Bank", "types": ["bank", "atm", "finance", "point_of_interest", "establishment"], "rating": 2.6, "user_ratings_total": 157, "geometry": {"lat": 12.9739087, "lng": 77.6466451}}
# {"name": "Bank of India - Jeevan Bhima Nagar Branch", "types": ["bank", "atm", "finance", "point_of_interest", "establishment"], "rating": 3.4, "user_ratings_total": 66, "geometry": {"lat": 12.9687544, "lng": 77.64945519999999}}
# {"name": "IndusInd Bank", "types": ["bank", "atm", "finance", "point_of_interest", "establishment"], "rating": 2.6, "user_ratings_total": 63, "geometry": {"lat": 12.969979, "lng": 77.647612}}
#
# [restaurants] sample:
# {"name": "Barbeque Nation - Indiranagar", "types": ["restaurant", "point_of_interest", "food", "establishment"], "rating": 4.2, "user_ratings_total": 21630, "geometry": {"lat": 12.9626604, "lng": 77.6414496}}
# {"name": "Toit", "types": ["bar", "restaurant", "point_of_interest", "food", "establishment"], "rating": 4.5, "user_ratings_total": 60561, "geometry": {"lat": 12.9795441, "lng": 77.6406542}}
# {"name": "Chaipatty Teafe", "types": ["cafe", "bakery", "restaurant", "point_of_interest", "food", "store", "establishment"], "rating": 3.8, "user_ratings_total": 1878, "geometry": {"lat": 12.9694775, "lng": 77.64110219999999}}
#
# [cafes] sample:
# {"name": "Chaipatty Teafe", "types": ["cafe", "restaurant", "bakery", "food", "store", "point_of_interest", "establishment"], "rating": 3.8, "user_ratings_total": 1878, "geometry": {"lat": 12.9694775, "lng": 77.64110219999999}}
# {"name": "Yogisthaan", "types": ["cafe", "gym", "restaurant", "food", "store", "lodging", "health", "point_of_interest", "establishment"], "rating": 4.2, "user_ratings_total": 3664, "geometry": {"lat": 12.9809695, "lng": 77.6384095}}
# {"name": "The Wishing Chair", "types": ["cafe", "home_goods_store", "food", "store", "point_of_interest", "establishment"], "rating": 4.2, "user_ratings_total": 367, "geometry": {"lat": 12.9789788, "lng": 77.6405758}}
#
# [fast_food] sample:
# {"name": "Pizza Hut | CMH Road, Bangalore", "types": ["meal_delivery", "meal_takeaway", "restaurant", "food", "point_of_interest", "establishment"], "rating": 4.4, "user_ratings_total": 3087, "geometry": {"lat": 12.9782299, "lng": 77.64052149999999}}
# {"name": "California Burrito Mexican Kitchen @ Indira Nagar", "types": ["meal_delivery", "meal_takeaway", "restaurant", "food", "point_of_interest", "establishment"], "rating": 4.3, "user_ratings_total": 3665, "geometry": {"lat": 12.9674465, "lng": 77.6366261}}
# {"name": "Leon's Burgers & Wings JBN", "types": ["cafe", "meal_takeaway", "restaurant", "food", "point_of_interest", "establishment"], "rating": 4.3, "user_ratings_total": 7422, "geometry": {"lat": 12.96906, "lng": 77.6489284}}
#
# [gyms] sample:
# {"name": "Yogisthaan", "types": ["gym", "cafe", "health", "lodging", "store", "restaurant", "food", "point_of_interest", "establishment"], "rating": 4.2, "user_ratings_total": 3664, "geometry": {"lat": 12.9809695, "lng": 77.6384095}}
# {"name": "Arya Samaj Mandir", "types": ["place_of_worship", "gym", "library", "health", "point_of_interest", "establishment"], "rating": 4, "user_ratings_total": 43, "geometry": {"lat": 12.9785003, "lng": 77.6391153}}
# {"name": "a1000yoga Academy", "types": ["gym", "health", "point_of_interest", "establishment"], "rating": 4.6, "user_ratings_total": 89, "geometry": {"lat": 12.9701314, "lng": 77.6476919}}
#
# [libraries] sample:
# {"name": "Arya Samaj Mandir", "types": ["place_of_worship", "library", "gym", "health", "point_of_interest", "establishment"], "rating": 4, "user_ratings_total": 43, "geometry": {"lat": 12.9785003, "lng": 77.6391153}}
# {"name": "City Central Library", "types": ["library", "point_of_interest", "establishment"], "rating": 4.6, "user_ratings_total": 406, "geometry": {"lat": 12.9680304, "lng": 77.6425441}}
# {"name": "Granthapura | Library & Bookstore", "types": ["library", "point_of_interest", "establishment"], "rating": 4.8, "user_ratings_total": 74, "geometry": {"lat": 12.9780684, "lng": 77.64037379999999}}
#
# [worship] sample:
# {"name": "Bengaluru", "types": ["locality", "political"], "rating": null, "user_ratings_total": null, "geometry": {"lat": 12.9628669, "lng": 77.57750899999999}}
# {"name": "jüSTa Indiranagar, Bangalore", "types": ["lodging", "point_of_interest", "establishment"], "rating": 4, "user_ratings_total": 566, "geometry": {"lat": 12.9712751, "lng": 77.6406725}}
# {"name": "The Golden Palms Hotel & Spa", "types": ["lodging", "point_of_interest", "establishment"], "rating": 4, "user_ratings_total": 688, "geometry": {"lat": 12.9777365, "lng": 77.6390918}}
#
# [nightlife] sample:
# {"name": "Toit", "types": ["restaurant", "food", "bar", "point_of_interest", "establishment"], "rating": 4.5, "user_ratings_total": 60561, "geometry": {"lat": 12.9795441, "lng": 77.6406542}}
# {"name": "Peacock", "types": ["restaurant", "food", "bar", "point_of_interest", "establishment"], "rating": 3.7, "user_ratings_total": 1926, "geometry": {"lat": 12.9749839, "lng": 77.6412556}}
# {"name": "Blistering Barnacles", "types": ["night_club", "restaurant", "food", "bar", "point_of_interest", "establishment"], "rating": 3.9, "user_ratings_total": 1132, "geometry": {"lat": 12.9754728, "lng": 77.6412507}}
#
# [cinemas] sample:
# {"name": "TEAM ADVAITH ACTING AND DIRECTION INSTITUTE | ACTING CLASSES | FILM INSTITUTE | INDIRANAGAR", "types": ["movie_theater", "point_of_interest", "establishment"], "rating": 5, "user_ratings_total": 69, "geometry": {"lat": 12.9717547, "lng": 77.6494531}}
#
# [parks] sample:
# {"name": "15th Main Park", "types": ["park", "point_of_interest", "establishment"], "rating": 3.9, "user_ratings_total": 56, "geometry": {"lat": 12.9655991, "lng": 77.645584}}
# {"name": "BBMP. Dr Vishnuvardhan Park", "types": ["park", "point_of_interest", "establishment"], "rating": 4.2, "user_ratings_total": 583, "geometry": {"lat": 12.9637544, "lng": 77.64290749999999}}
# {"name": "BDA Park Domlur", "types": ["park", "point_of_interest", "establishment"], "rating": 4, "user_ratings_total": 106, "geometry": {"lat": 12.9636632, "lng": 77.6357658}}
#
# [hotels] sample:
# {"name": "jüSTa Indiranagar, Bangalore", "types": ["lodging", "point_of_interest", "establishment"], "rating": 4, "user_ratings_total": 566, "geometry": {"lat": 12.9712751, "lng": 77.6406725}}
# {"name": "The Golden Palms Hotel & Spa", "types": ["lodging", "point_of_interest", "establishment"], "rating": 4, "user_ratings_total": 688, "geometry": {"lat": 12.9777365, "lng": 77.6390918}}
# {"name": "City Centre Residency", "types": ["lodging", "point_of_interest", "establishment"], "rating": 4, "user_ratings_total": 966, "geometry": {"lat": 12.9792818, "lng": 77.6374831}}
#
# [shops] sample:
# {"name": "Infants Store", "types": ["food", "store", "point_of_interest", "establishment"], "rating": null, "user_ratings_total": null, "geometry": {"lat": 12.972374, "lng": 77.6504901}}
# {"name": "Plants", "types": ["clothing_store", "store", "point_of_interest", "establishment"], "rating": 3.8, "user_ratings_total": 13, "geometry": {"lat": 12.9727387, "lng": 77.64855759999999}}
# {"name": "Sri Balaji enterprises", "types": ["store", "point_of_interest", "establishment"], "rating": 4.3, "user_ratings_total": 62, "geometry": {"lat": 12.9725044, "lng": 77.64914069999999}}
#
# [transit] sample:
# {"name": "Swami Vivekananda Road", "types": ["subway_station", "transit_station", "point_of_interest", "establishment"], "rating": 4.4, "user_ratings_total": 6459, "geometry": {"lat": 12.9859106, "lng": 77.645004}}
# {"name": "Halasuru Bus Stop", "types": ["transit_station", "point_of_interest", "establishment"], "rating": null, "user_ratings_total": null, "geometry": {"lat": 12.9790063, "lng": 77.6292859}}
# {"name": "Indira Nagar", "types": ["transit_station", "point_of_interest", "establishment"], "rating": 3.8, "user_ratings_total": 40, "geometry": {"lat": 12.978361, "lng": 77.640862}}

# %% [markdown]
# ## Notes
# - Google Places Nearby caps results per query (20 per page, up to ~60 with pagination). Counts in dense areas will be underestimates.
# - Geometry is point-only; no polygons. Area-based metrics (park area, road density) are not available from this endpoint.
# - Transit coverage may be sparse; `transit_station` is a coarse type. For precise metro/bus stops, OSM is usually richer.
# - If you need travel times/distances, call Distance Matrix on the nearest few POIs.
# - Respect Google Maps Platform Terms; avoid long-term storage beyond allowed caching.
